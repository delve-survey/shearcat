# %%
import astropy.io.fits as pf
import pylab as mplot
# %pylab inline
import numpy as np
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
old = pf.open('/project2/chihway/data/decade/shearcat_v1/metacal_output_DES1007-0333.fits')
new = pf.open('/project2/chihway/data/decade/shearcat_v1_test/metacal_output_DES1007-0333.fits')

# %%
old[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                 4004 / width of table in bytes
# NAXIS2  =                54913 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   72 / number of fields in each row
# TTYPE1  = 'id      '           / label for field   1
# TFORM1  = 'K       '           / data format of field: 8-byte INTEGER
# TTYPE2  = 'x       '           / label for field   2
# TFORM2  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE3  = 'y       '           / label for field   3
# TFORM3  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE4  = 'mcal_flags'         / label for field   4
# TFORM4  = 'K       '           / data format of field: 8-byte INTEGER
# ...

# %%
new[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                 5924 / width of table in bytes
# NAXIS2  =                54912 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   76 / number of fields in each row
# TTYPE1  = 'id      '           / label for field   1
# TFORM1  = 'K       '           / data format of field: 8-byte INTEGER
# TTYPE2  = 'x       '           / label for field   2
# TFORM2  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE3  = 'y       '           / label for field   3
# TFORM3  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE4  = 'mcal_flags'         / label for field   4
# TFORM4  = 'K       '           / data format of field: 8-byte INTEGER
# ...

# %%
len(old[1].data['id'])
# Out:
# 54913

# %%
len(new[1].data['id'])
# Out:
# 54912
