# %%
import healpy as hp
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import glob, sys
import fitsio
import chainconsumer
from tqdm import tqdm

# %%
plt.rcParams["axes.linewidth"]  = 1.0
plt.rcParams["xtick.major.size"]  = 10
plt.rcParams["xtick.minor.size"]  = 5
plt.rcParams["ytick.major.size"]  = 10
plt.rcParams["ytick.minor.size"]  = 5
plt.rcParams["xtick.direction"]  = "in"
plt.rcParams["ytick.direction"]  = "in"
plt.rcParams["legend.frameon"] = 'False'
plt.rcParams['figure.figsize'] = [10, 10]
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=13)

import os
if os.environ['USER'] == 'dhayaa':
    os.environ['PATH'] = f"{os.environ['PATH']}:/software/texlive-2022-el8-x86_64/bin/x86_64-linux/"

    
COLORS = ["f07167","219ebc","c767ac","E0A100","59a270"]
COLORS = ['#' + c if c[0] != '#' else c for c in COLORS ]

from cycler import cycler

# Update the default prop_cycle
plt.rcParams['axes.prop_cycle'] = cycler(color=COLORS)

# %% [markdown]
# # Read columns

# %%
metacal_columns = ['mcal_flux_noshear', 'mcal_T_noshear', 'mcal_T_ratio_noshear', 'mcal_s2n_noshear']

np.random.seed(42)
metacal_filelist = sorted(glob.glob('/project/chihway/dhayaa/DECADE/Tests/v08_RunDR3_Restart/metacal_*gplus.fits'))
metacal_filelist = [metacal_filelist[i] for i in np.random.choice(len(metacal_filelist), len(metacal_filelist), replace = False)]
metacal_filelist = metacal_filelist[:1000]

Tiles = [m.split('metacal_')[1][:12] for m in metacal_filelist]

Total_catalog = []

for f in tqdm(metacal_filelist):
    
    try:
        Total_catalog.append(fitsio.read(f, columns = metacal_columns))
    except:
        continue
    
Total_catalog_sim = np.concatenate(Total_catalog)


metacal_filelist = ['/project2/chihway/dhayaa/DECADE/TMPSTORE/metacal_output_%s.fits' % t for t in Tiles]

Total_catalog = []
for f in tqdm(metacal_filelist):
    
    try:
        Total_catalog.append(fitsio.read(f, columns = metacal_columns))
    except:
        continue
    
Total_catalog_data = np.concatenate(Total_catalog)
# Out:
# 100%|██████████| 1000/1000 [07:04<00:00,  2.36it/s]
# 100%|██████████| 1000/1000 [06:18<00:00,  2.64it/s]

# %%
def postprocess(X):
    
    new_array = np.zeros(len(X), 
                         dtype = [('SNR', '>f8'), 
                                  ('T', '>f8'),
                                  ('r', '>f8'),
                                  ('r-i', '>f8'),
                                  ('r-z', '>f8')
                                 ])
    
    new_array['SNR'] = X['mcal_s2n_noshear']
    new_array['T'] = X['mcal_T_noshear']
    new_array['r'] = X['mcal_flux_noshear'][:, 0]    
    
    Mask = ((new_array['r'] > 0) & (new_array['SNR'] > 0) & (new_array['T'] > -1))
    
    new_array = new_array[Mask]    
    
    new_array['SNR'] = np.log10(new_array['SNR'])
    new_array['T']   = np.log10(1 + new_array['T'])
    new_array['r'] = 30 - 2.5*np.log10(new_array['r'])
    
    i = 30 - 2.5*np.log10(X['mcal_flux_noshear'][:, 1])[Mask]
    z = 30 - 2.5*np.log10(X['mcal_flux_noshear'][:, 2])[Mask]
    
    Mask = ((new_array['r'] < 40) & (new_array['r'] > 14) & (i < 40) & (z < 40) & (new_array['T'] < 4.5))
    
    new_array = new_array[Mask]   
    
    new_array['r-i'] = new_array['r'] - i[Mask]
    new_array['r-z'] = new_array['r'] - z[Mask]
    
    print("SIZE:", len(new_array))
    return new_array

def dtype_to_float(X, t = '>f8'):
    
    return X.view(t).reshape(-1, len(X.dtype.names))

# %%
# def postprocess(X):
    
#     new_array = np.zeros(len(X), 
#                          dtype = [('SNR', '>f8'), 
#                                   ('T', '>f8'),
#                                   ('r', '>f8'),
#                                   ('r-i', '>f8'),
#                                   ('r-z', '>f8')
#                                  ])
    
#     new_array['SNR'] = X['mcal_s2n_noshear']
#     new_array['T'] = X['mcal_T_noshear']
#     new_array['r'] = X['mcal_flux_noshear'][:, 0]   
    
#     Tratio         = X['mcal_T_ratio_noshear'][:]
    
#     Mask = (new_array['r'] > 0) & (new_array['SNR'] > 10) & (new_array['SNR'] < 1000) & (new_array['T'] > -1) & (Tratio > 0.5)
    
#     new_array = new_array[Mask]    
    
#     new_array['SNR'] = np.log10(new_array['SNR'])
#     new_array['T']   = np.log10(1 + new_array['T'])
#     new_array['r'] = 30 - 2.5*np.log10(new_array['r'])
    
#     i = 30 - 2.5*np.log10(X['mcal_flux_noshear'][:, 1])[Mask]
#     z = 30 - 2.5*np.log10(X['mcal_flux_noshear'][:, 2])[Mask]
    
#     Mask = ((new_array['r'] < 26) & (new_array['r'] > 16) & (i < 23.5) & (i < 23.5) & (z < 26) & (new_array['T'] < 1))
    
#     new_array = new_array[Mask]   
    
#     new_array['r-i'] = new_array['r'] - i[Mask]
#     new_array['r-z'] = new_array['r'] - z[Mask]
    
#     print("SIZE:", len(new_array))
#     return new_array

# def dtype_to_float(X, t = '>f8'):
    
#     return X.view(t).reshape(-1, len(X.dtype.names))

# %%
from chainconsumer import ChainConsumer

plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=13)

param_names = [r"$\log_{10}(S/N)$", r"$\log_{10}(1 + T)$", 
               r"$r$", 
               r"$r-i$", 
               r"$r-z$"]
ranges = [(0.5, 2.5), 
          (-0.2, 0.4),
          (18, 30),
          (-4, 4),
          (-4, 4),]

c = ChainConsumer()

c.add_chain(dtype_to_float(postprocess(Total_catalog_sim))[::1],  parameters = param_names, name = 'Image Simulations')
c.add_chain(dtype_to_float(postprocess(Total_catalog_data))[::1], parameters = param_names, name = 'Data')

c.configure(sigmas = [0, 1, 2, 3], linewidths = 1, linestyles = ['-', ':'], spacing = 2, legend_kwargs = {'fontsize' : 13},
            colors=[COLORS[0], 'k'], shade = [True, False], shade_alpha=[0.7, 1.0], bar_shade=False, usetex=True, serif=True)

fig = c.plotter.plot()

for i in range(0, 25, 6):
    fig.axes[i].set_yscale('log')
    yy = fig.axes[i].get_children()[0]._y
    fig.axes[i].set_ylim(np.max(yy) * 1e-4, np.max(yy) * 5)
    fig.axes[i].set_yticks([])
fig.axes[0].text(4.9, 0.8, r'$\log_{10}(P)$', ha = 'right', color = 'k', alpha = 1.0, size = 13) #, transform = fig.axes[6].transAxes)


for j in range(0, 5):
    
    if j > 0:
        i = 1 + j*5
        tmp = fig.axes[i].get_xlim()
        fig.axes[i].axvspan(1.0, tmp[1], color = 'k', alpha = 0.05, zorder = -100)
        fig.axes[i].set_xlim(*tmp)
    else:
        i = 5
        tmp = fig.axes[i].get_ylim()
        fig.axes[i].axhspan(1.0, tmp[1], color = 'k', alpha = 0.05, zorder = -100)
        fig.axes[i].set_ylim(*tmp)
    
    i = 0 + j*5
    tmp = fig.axes[i].get_xlim()
    fig.axes[i].axvspan(3.0, tmp[1], color = 'k', alpha = 0.05, zorder = -100)
    fig.axes[i].axvspan(tmp[0], 1.0, color = 'k', alpha = 0.05, zorder = -100)
    fig.axes[i].set_xlim(*tmp)
    
plt.savefig('./Imsims_Triangle.pdf', dpi = 300, bbox_inches = 'tight')

# fig = c.plotter.plot(extents = ranges)
# Out:
# /home/dhayaa/ipykernel_2222364/1563780814.py:23: RuntimeWarning: invalid value encountered in log10
#   i = 30 - 2.5*np.log10(X['mcal_flux_noshear'][:, 1])[Mask]
# /home/dhayaa/ipykernel_2222364/1563780814.py:24: RuntimeWarning: invalid value encountered in log10
#   z = 30 - 2.5*np.log10(X['mcal_flux_noshear'][:, 2])[Mask]
# SIZE: 63901012
# SIZE: 38616493
